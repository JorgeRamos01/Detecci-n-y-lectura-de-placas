# %%
import platerecog as pr
import matplotlib.pyplot as plt

wdir = "data/"
#filename = wdir + "33.JPG"
filename = wdir + "67.JPG"
filename = wdir + "HPIM1040.JPG"

# Leemos imagen
recog = pr.ReconocePlaca(filename)


# Buscamos posibles placas
recog.encuentra_placas(tipo_prep = "canny")

for x,y,w,h in recog.lista_placas:
    plt.figure()
    plt.imshow(recog.img_re[y:y+h, x:x+w], interpolation = "bicubic")

# Buscamos posibles textos
print("Con Tesseract")
recog.placa_ocr(tipo_ocr = "tesseract")


for texto in recog.posibles_textos:
	print(texto)


print("\nCon KNN")
recog.placa_ocr(tipo_ocr = "knn")

for texto in recog.posibles_textos:
	print(texto)
# Out:
# Usando canny en la imagen se encontraron 5 posibles placas.
# Con Tesseract
# None
# None
# None
# None
# None
#
# Con KNN
# None
# None
# IZJ231JZ7
# None
# None

# %%
import cv2
wdir = "data/"
filename = wdir + "67.JPG"

# Leemos imagen
recog = pr.ReconocePlaca(filename)

# Buscamos posibles placas
recog.encuentra_placas(tipo_prep = "thresh1")

cnt = 0
for x,y,w,h in recog.lista_placas:
    plt.figure()
    cv2.imwrite("test" + str(cnt) + ".jpg", recog.img_re[y:y+h, x:x+w])
    plt.imshow(recog.img_re[y:y+h, x:x+w], interpolation = "bicubic")
    cnt += 1

# Buscamos posibles textos
print("Con Tesseract")
recog.placa_ocr(tipo_ocr = "tesseract")

for texto in recog.posibles_textos:
	print(texto)

print("\nCon KNN")
recog.placa_ocr(tipo_ocr = "knn")

for texto in recog.posibles_textos:
	print(texto)
# Out:
# En la imagen se encontraron 1 posibles placas.
# Con Tesseract
# None
#
# Con KNN
# YN7927I

# %%
wdir = "data/"
filename = wdir + "33.JPG"
filename = wdir + "67.JPG"

# Leemos imagen
recog = pr.ReconocePlaca(filename)

# Buscamos posibles placas
recog.encuentra_placas(tipo_prep = "thresh2")

#for x,y,w,h in recog.lista_placas:
    #plt.figure()
    #plt.imshow(recog.img_re[y:y+h, x:x+w], interpolation = "bicubic")

# Buscamos posibles textos
print("Con Tesseract")
recog.placa_ocr(tipo_ocr = "tesseract")

for texto in recog.posibles_textos:
	print(texto)

print("\nCon KNN")
recog.placa_ocr(tipo_ocr = "knn")

for texto in recog.posibles_textos:
	print(texto)
# Out:
# En la imagen se encontraron 2 posibles placas.
# Con Tesseract
# None
# None
#
# Con KNN
# YIMN797
# None

# %%
import platerecog as pr
import matplotlib.pyplot as plt
import cv2

wdir = "data/"
filename = wdir + "33.JPG"
filename = wdir + "HPIM1226.JPG"
filename = wdir + "HPIM1242.JPG"

# Leemos imagen
recog = pr.ReconocePlaca(filename)

# Buscamos posibles placas
recog.encuentra_placas(tipo_prep = "haar")

cnt = 0
for x,y,w,h in recog.lista_placas:
    plt.figure()
    cv2.imwrite("test" + str(cnt) + ".jpg", recog.img_re[y:y+h, x:x+w])
    plt.imshow(recog.img_re[y:y+h, x:x+w], interpolation = "bicubic")
    cnt += 1

# Buscamos posibles textos
print("Con Tesseract")
recog.placa_ocr(tipo_ocr = "tesseract")

for texto in recog.posibles_textos:
	print(texto)

print("\nCon KNN")
recog.placa_ocr(tipo_ocr = "knn")

for texto in recog.posibles_textos:
	print(texto)
# Out:
# Usando haar en la imagen se encontraron 1 posibles placas.
# Con Tesseract
#  YEWBSEZ
#
# Con KNN
# None

# %%
import platerecog as pr
import matplotlib.pyplot as plt
import cv2

wdir = "data/"
filename = wdir + "33.JPG"
#filename = wdir + "HPIM1226.JPG"
#filename = wdir + "HPIM1242.JPG"

# Leemos imagen
recog = pr.ReconocePlaca(filename)

# Buscamos posibles placas
recog.encuentra_placas(tipo_prep = "haar")

cnt = 0
for x,y,w,h in recog.lista_placas:
    plt.figure()
    cv2.imwrite("test" + str(cnt) + ".jpg", recog.img_re[y:y+h, x:x+w])
    plt.imshow(recog.img_re[y:y+h, x:x+w], interpolation = "bicubic")
    cnt += 1

# Buscamos posibles textos
print("Con Tesseract")
recog.placa_ocr(tipo_ocr = "tesseract")

for texto in recog.posibles_textos:
	print(texto)

print("\nCon KNN")
recog.placa_ocr(tipo_ocr = "knn")

for texto in recog.posibles_textos:
	print(texto)
# Out:
# Usando haar en la imagen se encontraron 1 posibles placas.
# Con Tesseract
# None
#
# Con KNN
# None
